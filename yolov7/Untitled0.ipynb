# %%
# !python --version
# Out:
# Python 3.8.10

# %%
import torch 
print(torch.__version__)
# Out:
# 1.13.1+cu116

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /mydrive

# %%
# %cd /mydrive/yolov7
# Out:
# /content/gdrive/My Drive/yolov7

# %%
# !git clone https://github.com/WongKinYiu/yolov7
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1127, done.
# remote: Total 1127 (delta 0), reused 0 (delta 0), pack-reused 1127
# Receiving objects: 100% (1127/1127), 69.93 MiB | 16.19 MiB/s, done.
# Resolving deltas: 100% (522/522), done.
# Updating files: 100% (104/104), done.

# %%
cd yolov7
# Out:
# /content/gdrive/My Drive/yolov7/yolov7

# %%
# !python train.py --workers 1 --device 0 --batch-size 8 --epochs 3000 --data /content/gdrive/MyDrive/yolov7/yolov7/dataset/data.yaml --img 640 640 --cfg /content/gdrive/MyDrive/yolov7/yolov7/cfg/training/yolov7.yaml  --weights 'yolov7.pt' --name yolov7_project_ind --hyp /content/gdrive/MyDrive/yolov7/yolov7/data/hyp.scratch.p5.yaml
# Out:
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='/content/gdrive/MyDrive/yolov7/yolov7/cfg/training/yolov7.yaml', data='/content/gdrive/MyDrive/yolov7/yolov7/dataset/data.yaml', device='0', entity=None, epochs=3000, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='/content/gdrive/MyDrive/yolov7/yolov7/data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7_project_ind', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7_project_ind2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, v5_metric=False, weights='yolov7.pt', workers=1, world_size=1)
# ...

# %%
# !python train.py --weights /content/gdrive/MyDrive/yolov7/yolov7/runs/train/yolov7_project_ind2/weights/last.pt --resume
# Out:
# Resuming training from ./runs/train/yolov7_project_ind2/weights/last.pt
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='/content/gdrive/MyDrive/yolov7/yolov7/dataset/data.yaml', device='0', entity=None, epochs=3000, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='/content/gdrive/MyDrive/yolov7/yolov7/data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7_project_ind', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=True, save_dir='runs/train/yolov7_project_ind2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, v5_metric=False, weights='./runs/train/yolov7_project_ind2/weights/last.pt', workers=1, world_size=1)
# ...

# %%
# !python train.py --weights /content/gdrive/MyDrive/yolov7/yolov7/runs/train/yolov7_project_ind2/weights/last.pt --resume
# Out:
# Resuming training from ./runs/train/yolov7_project_ind2/weights/last.pt
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='/content/gdrive/MyDrive/yolov7/yolov7/dataset/data.yaml', device='0', entity=None, epochs=225, evolve=False, exist_ok=False, freeze=[0], global_rank=-1, hyp='/content/gdrive/MyDrive/yolov7/yolov7/data/hyp.scratch.p5.yaml', image_weights=False, img_size=[640, 640], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='yolov7_project_ind', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=True, save_dir='runs/train/yolov7_project_ind2', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, v5_metric=False, weights='./runs/train/yolov7_project_ind2/weights/last.pt', workers=1, world_size=1)
# ...

# %%
# !python detect.py --weights /content/gdrive/MyDrive/yolov7/yolov7/runs/train/yolov7_project_ind2/weights/best.pt --conf 0.25 --img-size 640 --source /content/gdrive/MyDrive/yolov7/yolov7/19.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', no_trace=False, nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='/content/gdrive/MyDrive/yolov7/yolov7/19.jpg', update=False, view_img=False, weights=['/content/gdrive/MyDrive/yolov7/yolov7/runs/train/yolov7_project_ind2/weights/best.pt'])
# YOLOR 🚀 v0.1-121-g2fdc7f1 torch 1.13.1+cu116 CUDA:0 (Tesla T4, 15109.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36692138 parameters, 6194944 gradients
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# ...
